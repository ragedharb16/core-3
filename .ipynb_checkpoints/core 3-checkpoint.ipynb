# %%
import pandas as pd 
import numpy as np

# %%
df1 =pd.read_csv("C:\\Users\\raged\\OneDrive\\Documentos\\GitHub\\core-3\\superhero_info - superhero_info.csv")

# %%
df2= pd.read_csv("C:\\Users\\raged\\OneDrive\\Documentos\\GitHub\\core-3\\superhero_powers - superhero_powers.csv")
df2
# Out:
#           hero_names                                             Powers
# 0            3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1             A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2         Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3           Abin Sur                                 Lantern Power Ring
# 4        Abomination  Accelerated Healing,Intelligence,Super Strengt...
# ..               ...                                                ...
# 662  Yellowjacket II                 Flight,Energy Blasts,Size Changing
# 663             Ymir  Cold Resistance,Durability,Longevity,Super Str...
# 664             Yoda  Agility,Stealth,Danger Sense,Marksmanship,Weap...
# 665          Zatanna  Cryokinesis,Telepathy,Magic,Fire Control,Proba...
# 666             Zoom  Super Speed,Intangibility,Time Travel,Time Man...
#
# [667 rows x 2 columns]

# %%
df1[["Hero", "Publisher"]] = df1['Hero|Publisher'].str.split("|", expand =True)
df1.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# ...

# %%
df1 = df1.drop(columns = ["Hero|Publisher"])
df1.head(0)
# Out:
# Empty DataFrame
# Columns: [Gender, Race, Alignment, Hair color, Eye color, Skin color, Measurements, Hero, Publisher]
# Index: []

# %%
probe = df1.loc[0,'Measurements']
probe
# Out:
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
type(probe)
# Out:
# str

# %%
#Replacing the single quotation with the double quotation mark
df1['Measurements'] = df1['Measurements'].str.replace("'", '"')
df1
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color                                  Measurements             Hero  \
# ...

# %%
probe2= df1.loc[0,'Measurements']
probe2
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
import json
mesur= json.loads(probe2)

# %%
type(mesur)
# Out:
# dict

# %%
#Applying .json.loads to the entire column
df1['Measurements'] = df1["Measurements"].apply(json.loads)

# %%
#Converting into a series
df1[["Height(cm)", "Weight(kg)"]] = df1["Measurements"].apply(pd.Series)
df1.drop(columns='Measurements', inplace=True)

# %%
df1
# Out:
#      Gender               Race Alignment        Hair color Eye color  \
# 0      Male              Human      good           No Hair    yellow
# 1      Male      Icthyo Sapien      good           No Hair      blue
# 2      Male            Ungaran      good           No Hair      blue
# 3      Male  Human / Radiation       bad           No Hair     green
# 4      Male              Human       bad           No Hair      blue
# ..      ...                ...       ...               ...       ...
# 458    Male              Human      good             Blond      blue
# 459  Female              Human      good  Strawberry Blond      blue
# 460    Male     Yoda's species      good             White     brown
# 461  Female              Human      good             Black      blue
# 462    Male            Unknown       bad             Brown       red
#
#     Skin color             Hero          Publisher Height(cm) Weight(kg)
# ...

# %%
replace_list = [" ", "cm"]
for char in replace_list:
    
    df1["Height(cm)"] = df1["Height(cm)"].str.replace(char, "", regex= False)

# %%
#Converting column into a numeric format (int)
df1["Height(cm)"] =pd.to_numeric(df1["Height(cm)"]).astype(int)
df1["Height(cm)"].dtype
# Out:
# dtype('int32')

# %%
#Getting rid of all white spaces and measurement units using a loop
replace_list = [" ", "kg"]
for char in replace_list:
    
    df1["Weight(kg)"] = df1["Weight(kg)"].str.replace(char, "", regex= False)

# %%
df1["Weight(kg)"] =pd.to_numeric(df1["Weight(kg)"]).astype(int)
df1["Weight(kg)"].dtype
# Out:
# dtype('int32')

# %%
df2['Powers_split'] = df2['Powers'].str.split(',')
df2.head()
# Out:
#     hero_names                                             Powers  \
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...
#
#                                         Powers_split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...
# 2  [Agility, Accelerated Healing, Cold Resistance...
# 3                               [Lantern Power Ring]
# 4  [Accelerated Healing, Intelligence, Super Stre...

# %%
superpowers = df2["Powers"].str.split(",")
superpowers
# Out:
# 0        [Agility, Super Strength, Stamina, Super Speed]
# 1      [Accelerated Healing, Durability, Longevity, S...
# 2      [Agility, Accelerated Healing, Cold Resistance...
# 3                                   [Lantern Power Ring]
# 4      [Accelerated Healing, Intelligence, Super Stre...
#                              ...
# 662               [Flight, Energy Blasts, Size Changing]
# 663    [Cold Resistance, Durability, Longevity, Super...
# 664    [Agility, Stealth, Danger Sense, Marksmanship,...
# 665    [Cryokinesis, Telepathy, Magic, Fire Control, ...
# 666    [Super Speed, Intangibility, Time Travel, Time...
# Name: Powers, Length: 667, dtype: object

# %%
superpowers.explode("Powers")
superpowers.explode("Powers").value_counts()
# Out:
# Super Strength           360
# Stamina                  289
# Durability               257
# Super Speed              249
# Agility                  242
#                         ...
# Electrical Transport       1
# Molecular Dissipation      1
# Banish                     1
# Biokinesis                 1
# Changing Armor             1
# Name: Powers, Length: 167, dtype: int64

# %%
new_column = superpowers.explode("Powers").dropna().unique()
new_column
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
#One Hot Encoding the newly made colums of super hero powers
for col in new_column:
    df2[col] = df2['Powers'].str.contains(col)
df2.head(3)
# Out:
# C:\Users\raged\anaconda3\envs\dojo-env\lib\site-packages\ipykernel_launcher.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   This is separate from the ipykernel package so we can avoid doing imports until
#    hero_names                                             Powers  \
# 0     3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1      A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2  Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
#
#                                         Powers_split  Agility  Super Strength  \
# 0    [Agility, Super Strength, Stamina, Super Speed]     True            True
# 1  [Accelerated Healing, Durability, Longevity, S...    False            True
# ...

# %%
df2= df2.drop(columns = ["Powers","Powers_split"])

# %%
df2 = df2.rename(columns = {"hero_names": "Hero"})
df2.head()
# Out:
#           Hero  Agility  Super Strength  Stamina  Super Speed  \
# 0      3-D Man     True            True     True         True
# 1       A-Bomb    False            True     True        False
# 2   Abe Sapien     True            True     True        False
# 3     Abin Sur    False           False    False        False
# 4  Abomination    False            True     True         True
#
#    Accelerated Healing  Durability  Longevity  Camouflage  Self-Sustenance  \
# 0                False       False      False       False            False
# 1                 True        True       True        True             True
# 2                 True        True       True       False            False
# 3                False       False      False       False            False
# 4                 True       False      False       False            False
#
#    ...  Weather Control  Omnipresent  Omniscient  Hair Manipulation  \
# 0  ...            False        False       False              False
# ...

# %%
heros_df =pd.merge(df1, df2, how="outer", on="Hero")

# %%
heros_df
# Out:
#     Gender               Race Alignment Hair color Eye color Skin color  \
# 0     Male              Human      good    No Hair    yellow    Unknown
# 1     Male      Icthyo Sapien      good    No Hair      blue       blue
# 2     Male            Ungaran      good    No Hair      blue        red
# 3     Male  Human / Radiation       bad    No Hair     green    Unknown
# 4     Male              Human       bad    No Hair      blue    Unknown
# ..     ...                ...       ...        ...       ...        ...
# 670    NaN                NaN       NaN        NaN       NaN        NaN
# 671    NaN                NaN       NaN        NaN       NaN        NaN
# 672    NaN                NaN       NaN        NaN       NaN        NaN
# 673    NaN                NaN       NaN        NaN       NaN        NaN
# 674    NaN                NaN       NaN        NaN       NaN        NaN
#
#               Hero          Publisher  Height(cm)  Weight(kg)  ...  \
# ...

# %%
speed =heros_df.groupby(["Super Speed"])['Weight(kg)'].mean().round()
speed
# Out:
# Super Speed
# False    102.0
# True     129.0
# Name: Weight(kg), dtype: float64

# %%
group_publisher = heros_df.groupby(["Publisher"])['Height(cm)'].mean()
group_publisher
# Out:
# Publisher
# DC Comics            181.920290
# Dark Horse Comics    176.909091
# George Lucas         159.600000
# Image Comics         211.000000
# Marvel Comics        191.545455
# Shueisha             171.500000
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Name: Height(cm), dtype: float64
